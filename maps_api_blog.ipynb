# %%
import time
import googlemaps
import geopandas as gpd
from shapely.geometry import Point
from geojsonio import display

# %%
class Gmaps_Search():
    # initialize class by defining api key and search query constaints
    def __init__(self, api_key, place_type):
        self.key = api_key
        self.type = place_type
    
    # search location within specified city
    def search_query(self, city):
        # authenticate user 
        gmaps = googlemaps.Client(key=self.key)
        
        # extract lat long coordinates of specified city
        request = gmaps.find_place(city + ', Philippines', 'textquery', ['name', 'geometry'])
        lat = request['candidates'][0]['geometry']['location']['lat']
        lng = request['candidates'][0]['geometry']['location']['lng']

        # return nearest 60 location given city coordinates
        results = list()
        request = gmaps.places_nearby({'lat':lat, 'lng':lng}, rank_by='distance', type=self.type, keyword=city)
        results += request['results']
        for j in range(2):
            time.sleep(3)
            try:
                request = gmaps.places_nearby({'lat':lat, 'lng':lng}, rank_by='distance', type=self.type,
                                            keyword=city, page_token=request['next_page_token'])
                results += request['results']
            except KeyError:
                break
        
        # transform results from dictionary to geodataframe
        name = [result['name'] for result in results]
        geoloc_list = [[result['geometry']['location']['lat'], result['geometry']['location']['lng']] for result in results]
        output = gpd.GeoDataFrame(zip(name, geometry), columns=['name', 'geometry'])
        return output

# %%
gmaps = Gmaps_Search('AIzaSyBieNbkAHNHhEyCF6Ncvg3V9noZCXFfJ0E', 'cafe')

results = gmaps.search_query('Manila')

# %%
points = [Point(geo) for geo in geometry]

# %%
x=gpd.GeoDataFrame(zip(name, geometry), columns=['name', 'geometry'])

# %%
x[:10]
# Out:
#                       name                   geometry
# 0              Landap Café  [14.5963198, 120.9848802]
# 1                  The Den  [14.5988397, 120.9794994]
# 2            RedStraw Cafe    [14.60058, 120.9902617]
# 3     Beyond Coffee Manila  [14.6057432, 120.9874379]
# 4            Mindbrew Cafe   [14.606581, 120.9868982]
# 5  Awi's Cafe & Restaurant  [14.5994446, 120.9762528]
# 6           Café Mezzanine  [14.6004321, 120.9755151]
# 7    Amo Yamie Crib España  [14.6065922, 120.9897537]
# 8              Bo's Coffee    [14.590133, 120.983017]
# 9        Coffee Indulgence  [14.6083067, 120.9878695]

# %%
display(x.to_json())
# Out:
# 'http://geojson.io/#data=data:application/json,%7B%22type%22%3A%20%22FeatureCollection%22%2C%20%22features%22%3A%20%5B%7B%22id%22%3A%20%220%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Landap%20Caf%5Cu00e9%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.5963198%2C%20120.9848802%5D%7D%7D%2C%20%7B%22id%22%3A%20%221%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22The%20Den%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.5988397%2C%20120.9794994%5D%7D%7D%2C%20%7B%22id%22%3A%20%222%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22RedStraw%20Cafe%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.60058%2C%20120.9902617%5D%7D%7D%2C%20%7B%22id%22%3A%20%223%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Beyond%20Coffee%20Manila%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6057432%2C%20120.9874379%5D%7D%7D%2C%20%7B%22id%22%3A%20%224%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Mindbrew%20Cafe%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.606581%2C%20120.9868982%5D%7D%7D%2C%20%7B%22id%22%3A%20%225%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Awi%27s%20Cafe%20%26%20Restaurant%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.5994446%2C%20120.9762528%5D%7D%7D%2C%20%7B%22id%22%3A%20%226%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Caf%5Cu00e9%20Mezzanine%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6004321%2C%20120.9755151%5D%7D%7D%2C%20%7B%22id%22%3A%20%227%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Amo%20Yamie%20Crib%20Espa%5Cu00f1a%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6065922%2C%20120.9897537%5D%7D%7D%2C%20%7B%22id%22%3A%20%228%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Bo%27s%20Coffee%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.590133%2C%20120.983017%5D%7D%7D%2C%20%7B%22id%22%3A%20%229%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Coffee%20Indulgence%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6083067%2C%20120.9878695%5D%7D%7D%2C%20%7B%22id%22%3A%20%2210%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Cafe%20Aquatica%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6003691%2C%20120.9744517%5D%7D%7D%2C%20%7B%22id%22%3A%20%2211%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Costa%20Coffee%20SM%20Manila%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.5896465%2C%20120.9840018%5D%7D%7D%2C%20%7B%22id%22%3A%20%2212%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Bloque%207%20Cafe%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.5906932%2C%20120.9762435%5D%7D%7D%2C%20%7B%22id%22%3A%20%2213%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Governor%27s%20Cafe%20Manila%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coordinates%22%3A%20%5B14.6056233%2C%20120.9964581%5D%7D%7D%2C%20%7B%22id%22%3A%20%2214%22%2C%20%22type%22%3A%20%22Feature%22%2C%20%22properties%22%3A%20%7B%220%22%3A%20%22Cafe%20UK%20Dapitan%22%7D%2C%20%22geometry%22%3A%20%7B%22type%22%3A%20%22Point%22%2C%20%22coo ...

# %%
pd.DataFrame(zip(name, geoloc_list), columns=['name', 'geoloc'])
# Out:
#                                                 name                    geoloc
# 0                                        Landap Café  [14.5963198, 14.5963198]
# 1                                            The Den  [14.5988397, 14.5988397]
# 2                                      RedStraw Cafe      [14.60058, 14.60058]
# 3                               Beyond Coffee Manila  [14.6057432, 14.6057432]
# 4                                      Mindbrew Cafe    [14.606581, 14.606581]
# 5                            Awi's Cafe & Restaurant  [14.5994446, 14.5994446]
# 6                                     Café Mezzanine  [14.6004321, 14.6004321]
# 7                              Amo Yamie Crib España  [14.6065922, 14.6065922]
# 8                                        Bo's Coffee    [14.590133, 14.590133]
# 9                                  Coffee Indulgence  [14.6083067, 14.6083067]
# 10                                     Cafe Aquatica  [14.6003691, 14.6003691]
# 11                            Costa Coffee SM Manila  [14.5896465, 14.5896465]
# 12                                     Bloque 7 Cafe  [14.5906932, 14.5906932]
# 13                            Governor's Cafe Manila  [14.6056233, 14.6056233]
# 14                                   Cafe UK Dapitan  [14.6125515, 14.6125515]
# 15                               iChill Theater Cafe  [14.6127404, 14.6127404]
# 16                                      Costa Coffee  [14.5758315, 14.5758315]
# 17                 OZ RACING The Wedding Cafe Manila  [14.5796185, 14.5796185]
# 18                           Los Angeles Cafe Manila    [14.574612, 14.574612]
# 19                                          Advocafe  [14.5723116, 14.5723116]
# 20                                       R:SE Manila  [14.5993562, 14.5993562]
# 21                                 933 Coworking Mnl  [14.6065298, 14.6065298]
# 22                                       Cafe France  [14.6005216, 14.6005216]
# 23                                      Barcelo Cafe  [14.5977976, 14.5977976]
# 24                                        Cafe Tomas    [14.607955, 14.607955]
# 25                                          AdvoCafe  [14.5984078, 14.5984078]
# 26                           Cioccolata Churros Cafe  [14.5899336, 14.5899336]
# 27                                        Floti Cafe  [14.6048838, 14.6048838]
# 28                                  Paper + Cup Café  [14.5882649, 14.5882649]
# 29                                        Floti Cafe  [14.6084711, 14.6084711]
# 30                                       Tim Hortons  [14.5835082, 14.5835082]
# 31                                   Mary Grace Cafe  [14.5753478, 14.5753478]
# 32                                         Cafe Esso  [14.5747122, 14.5747122]
# 33                                  Default Cafe Pub    [14.572714, 14.572714]
# 34                                     La Scala Café  [14.5722173, 14.5722173]
# 35                                         KSEM Kafe  [14.5723322, 14.5723322]
# 36                                     blocleaf café  [14.5704603, 14.5704603]
# 37                               Diligence Cafe Taft    [14.571017, 14.571017]
# 38                                    Yuchi's Coffee  [14.5757551, 14.5757551]
# 39                                           Noriter  [14.5645842, 14.5645842]
# 40                        The Coffee Bean & Tea Leaf  [14.6010399, 14.6010399]
# 41                                   1919 Grand Cafe  [14.5962693, 14.5962693]
# 42  Foss Coffee Kiosk Manila (Dona Carmen Apartment)  [14.5988734, 14.5988734]
# 43                                    BeanQuest Café  [14.6088756, 14.6088756]
# 44                                     Sidewalk Cafe      [14.60443, 14.60443]
# 45                                      A Small Cafe    [14.607553, 14.607553]
# 46                                         Starbucks  [14.5938908, 14.5938908]
# 47                              Antigo Café & Bistro  [14.5923332, 14.5923332]
# 48                                     Café Pression  [14.5885735, 14.5885735]
# 49                                    Selah 1st Cafe  [14.6108596, 14.6108596]
# 50                  Residencia De Manila Coffee Shop  [14.6114342, 14.6114342]
# 51                        The Coffee Bean & Tea Leaf  [14.5758315, 14.5758315]
# 52    Recipes By Cafe Metro - Robinsons Place Manila    [14.574944, 14.574944]
# 53                                 Old Manila Coffee  [14.5708221, 14.5708221]
# 54                                  Prominent Manila  [14.6344697, 14.6344697]
# 55                          TableTaft Boardgame Café  [14.5631669, 14.5631669]
# 56                                       8065 Coffee  [14.5644891, 14.5644891]
# 57                                   4th Street Cafe    [14.614164, 14.614164]
# 58                                       LeTeus Cafe  [14.5497699, 14.5497699]
# 59                                  Yardstick Coffee    [14.556733, 14.556733]

# %%
(request['results'])
# Out:
# [{'geometry': {'location': {'lat': 14.5994981, 'lng': 120.9842141},
#    'viewport': {'northeast': {'lat': 14.60084292989272,
#      'lng': 120.9855935798928},
#     'southwest': {'lat': 14.59814327010728, 'lng': 120.9828939201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '7b2a4af3999b8921654c434f659368c2f0efe1fc',
#   'name': "Cafe Alyana's",
#   'place_id': 'ChIJAZSB0RzKlzMRKi-pYmyWmso',
#   'plus_code': {'compound_code': 'HXXM+QM Manila, Metro Manila',
#    'global_code': '7Q62HXXM+QM'},
#   'rating': 0,
#   'reference': 'ChIJAZSB0RzKlzMRKi-pYmyWmso',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0,
#   'vicinity': '2751 New Panaderos St, Bgy 905, Zone 100 STA Ana, Manila'},
#  {'geometry': {'location': {'lat': 14.5963198, 'lng': 120.9848802},
#    'viewport': {'northeast': {'lat': 14.59765342989272,
#      'lng': 120.9862294298927},
#     'southwest': {'lat': 14.59495377010728, 'lng': 120.9835297701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'f2b3e49c266e3dccde6ea9ef32bd02b2349decdd',
#   'name': 'Landap Café',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113878842024193042926">Dos Ocampo</a>'],
#     'photo_reference': 'CmRaAAAABU5cSgEb9zLyR5kjHyYn3nziXiABjvkXibqJqozRw-fDdtXgHfubUpyv-tzBD1ZxTJCfaTpuk1Bp_VmohgXuArCZjzhbrfBb4NMf71bYXSD5yoYx7KZyG3uTW1RVihn-EhCk7rIjL6Z3TkFCId4zitAcGhSQHsRGaqTbGD_nMnzUMRSL_wLHpg',
#     'width': 3264}],
#   'place_id': 'ChIJcQ8Wsx3KlzMRqXZ8evrcwvY',
#   'plus_code': {'compound_code': 'HXWM+GX Manila, Metro Manila',
#    'global_code': '7Q62HXWM+GX'},
#   'rating': 4.2,
#   'reference': 'ChIJcQ8Wsx3KlzMRqXZ8evrcwvY',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 5,
#   'vicinity': 'Globo de Oro St, Quiapo, Manila'},
#  {'geometry': {'location': {'lat': 14.5988397, 'lng': 120.9794994},
#    'viewport': {'northeast': {'lat': 14.60015697989272,
#      'lng': 120.9808821798927},
#     'southwest': {'lat': 14.59745732010728, 'lng': 120.9781825201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'eb20597341b7226283e8d35ffa1cf6403c1f5041',
#   'name': 'The Den',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105466500452414206409">Frenchy Colin</a>'],
#     'photo_reference': 'CmRaAAAAGaWEU6WcV414zOiv1Hfiimj7fCwf5nxS6ejco_ANH184yZZ_6OayRfSJivstpi8fUG5jhC5BUpLw2Ikd6FmWd4xA4ypT9EwOmT8xmDE0R7WSulrx-TmOZ5h9UoqR_I8BEhDWOsla7Sv29SmUoFgVhzfiGhQG_panA5w55JUbal1NC0iJrG_z9g',
#     'width': 4032}],
#   'place_id': 'ChIJV8q4GxvKlzMRnjt6wydJKNo',
#   'plus_code': {'compound_code': 'HXXH+GQ Manila, Metro Manila',
#    'global_code': '7Q62HXXH+GQ'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJV8q4GxvKlzMRnjt6wydJKNo',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 98,
#   'vicinity': 'HUB Make Lab, First United Building, 413 Escolta St, Binondo, Manila'},
#  {'geometry': {'location': {'lat': 14.6057432, 'lng': 120.9874379},
#    'viewport': {'northeast': {'lat': 14.60703577989272,
#      'lng': 120.9887804798927},
#     'southwest': {'lat': 14.60433612010728, 'lng': 120.9860808201072}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '7bf67a238a5f7d4f7991e50d105e5a6b8e30abf4',
#   'name': 'Beyond Coffee Manila',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117693255481737060681">Beyond Coffee</a>'],
#     'photo_reference': 'CmRaAAAAgcNHAsSSvjw8OH-BP0Bh7lWiKE8axvgO9KOv20vB8uJzEY7gnEBJ4HJQvir3nQ6L3zT4q5Fmjy1R2Nmx_hGBKRRTeh7DVW8LDMlNqN7JDCi130vVxak-UAb9Cx_fJMhhEhAnf2vyq_HD4lvsSaCEHVG7GhRgSqqhj4HteQphDMydeeVqTQfnzA',
#     'width': 3264}],
#   'place_id': 'ChIJwb2x4QHKlzMRE-H0iD2UKPs',
#   'plus_code': {'compound_code': 'JX4P+7X Manila, Metro Manila',
#    'global_code': '7Q62JX4P+7X'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJwb2x4QHKlzMRE-H0iD2UKPs',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 106,
#   'vicinity': '928 P. Paredes St, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.606581, 'lng': 120.9868982},
#    'viewport': {'northeast': {'lat': 14.60789667989272,
#      'lng': 120.9882809798927},
#     'southwest': {'lat': 14.60519702010728, 'lng': 120.9855813201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'bbdd87fb8d88001d5bdf1bff6b84d062fbef7217',
#   'name': 'Mindbrew Cafe',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 810,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112130760635358994973">A Google User</a>'],
#     'photo_reference': 'CmRaAAAA3Geur4RO-uPySWYJ1g9ewDfq5246aggp7mjgc3s4sm-pMcA420RUK51c7_PZZuGaPlxgyvbmHTz4qd2E_JH_VZeFwuLgXHuqmjDAqbVxVnbzUAKxmRWEKwZqiYNPwvnHEhArosJvW6l8nYBuQor9pW8PGhSj1YtYrWWUqn7Q6ubzVWsyn91F9A',
#     'width': 1080}],
#   'place_id': 'ChIJIwzVGAG2lzMRbJHg2yvbgdg',
#   'plus_code': {'compound_code': 'JX4P+JQ Manila, Metro Manila',
#    'global_code': '7Q62JX4P+JQ'},
#   'rating': 4.5,
#   'reference': 'ChIJIwzVGAG2lzMRbJHg2yvbgdg',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 18,
#   'vicinity': '1111 I. Delos Reyes Street, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.6004321, 'lng': 120.9755151},
#    'viewport': {'northeast': {'lat': 14.60179282989272,
#      'lng': 120.9768969298927},
#     'southwest': {'lat': 14.59909317010728, 'lng': 120.9741972701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '683c5e093d43d3948c29c87b6364ee8ef8ba8211',
#   'name': 'Café Mezzanine',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116900802599741720903">Richard Francisco</a>'],
#     'photo_reference': 'CmRaAAAA69aFfBv_wpFq_ZXM676WPYKE3D6QpAWTGhhsffE_r7LkyqMwcmRLyR5cALfJLgWp8AP0JODol8keBqfq1744VUAQTHvaHPlh5xU5B7mAoK7oZGpA6fz4hi9TxH6kRF2BEhBDqBuxmnPcGzfxUDIqrC5mGhRupEJP1FGYtsgfUNmKhD0NFSZhuA',
#     'width': 4608}],
#   'place_id': 'ChIJDb32ERDKlzMRe_QtiLZ5dR8',
#   'plus_code': {'compound_code': 'JX2G+56 Manila, Metro Manila',
#    'global_code': '7Q62JX2G+56'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJDb32ERDKlzMRe_QtiLZ5dR8',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 293,
#   'vicinity': '650 Ongpin St, Binondo, Manila'},
#  {'geometry': {'location': {'lat': 14.5962693, 'lng': 120.9758092},
#    'viewport': {'northeast': {'lat': 14.59764302989272,
#      'lng': 120.9772000798927},
#     'southwest': {'lat': 14.59494337010728, 'lng': 120.9745004201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'b1a7b74deba7008a2493fbe22f603f7c7e1d830c',
#   'name': '1919 Grand Cafe',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 928,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113314526513394141190">Michael Co</a>'],
#     'photo_reference': 'CmRaAAAA6fheLKjUGppEbHyw7ufJOaQKPkt8ZlxBtzgwo9c5KKN3KHMX-BC3C8xxJZGb0bH4T2TvQWJSz2UETu-uPME2uupj0nCca2REROpR9-ddopGPtUKNoaYz1DzMePYF2QtoEhAfOrNGyAhRJMAHWSWKJ0MeGhTdWgflyJdn4pYXpTICkvLt_-_JWA',
#     'width': 1920}],
#   'place_id': 'ChIJe6y6OYXLlzMR38iigYnPnRc',
#   'plus_code': {'compound_code': 'HXWG+G8 Manila, Metro Manila',
#    'global_code': '7Q62HXWG+G8'},
#   'rating': 4.3,
#   'reference': 'ChIJe6y6OYXLlzMR38iigYnPnRc',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 331,
#   'vicinity': '117 Juan Luna St, Binondo, Manila'},
#  {'geometry': {'location': {'lat': 14.6065922, 'lng': 120.9897537},
#    'viewport': {'northeast': {'lat': 14.60787807989272,
#      'lng': 120.9910638298927},
#     'southwest': {'lat': 14.60517842010728, 'lng': 120.9883641701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'ed8c7df6cc3cc4ee3e0cdde402a008214aaea462',
#   'name': 'Amo Yamie Crib España',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113777030162445266903">Aldren Aldema</a>'],
#     'photo_reference': 'CmRaAAAAcQIf8V001cR2uf_PCXogaaO2pbQx3phRvqJ2wfwYXhWerc97YMwfdw11D3NEqHnTOIgfuAkLMIF76mEe4UekJwKUjx4B72Lg1cyd8mcHsFHdRoitLIZiOijPOb3Jua94EhASrsLPhf2v3O_Qre9fzACyGhQySXXQkOxjX3GAwn-ma0B8OIW7uA',
#     'width': 4160}],
#   'place_id': 'ChIJMeq-CP_JlzMRiXGTUgbSSac',
#   'plus_code': {'compound_code': 'JX4Q+JW Manila, Metro Manila',
#    'global_code': '7Q62JX4Q+JW'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJMeq-CP_JlzMRiXGTUgbSSac',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 397,
#   'vicinity': 'DB Building, 1250 España Blvd, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.6003691, 'lng': 120.9744517},
#    'viewport': {'northeast': {'lat': 14.60169117989272,
#      'lng': 120.9758213798927},
#     'southwest': {'lat': 14.59899152010728, 'lng': 120.9731217201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'd547fc0a21061d92ba2809f5c5ecda7731772c12',
#   'name': 'Cafe Aquatica',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2268,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108915765707927065058">A Google User</a>'],
#     'photo_reference': 'CmRaAAAAxmdLMO9-RvTRarZ6u58OfyNCBgQKSufKLFIlNRBTYyrFfObs78lw2vhKGgYMtDW_K7JvUlfOcDaiv_LQCRCfUnaJ-LghJPirsVlshiBCD88iNhCgigY90J-f3xHSm59IEhBOiMbR5_ULS0NRGHmLWd4iGhS03-HeuCCD6oyImWSbe4yvfL2neA',
#     'width': 4032}],
#   'place_id': 'ChIJx7ZYPhDKlzMRrRvvqMRNa2s',
#   'plus_code': {'compound_code': 'JX2F+4Q Manila, Metro Manila',
#    'global_code': '7Q62JX2F+4Q'},
#   'rating': 4.5,
#   'reference': 'ChIJx7ZYPhDKlzMRrRvvqMRNa2s',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 40,
#   'vicinity': '619 Norberto Ty St, Binondo, Manila'},
#  {'geometry': {'location': {'lat': 14.6088756, 'lng': 120.9870974},
#    'viewport': {'northeast': {'lat': 14.61014177989272,
#      'lng': 120.9885230798927},
#     'southwest': {'lat': 14.60744212010728, 'lng': 120.9858234201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '4f339698cf57e92fba4690b459899fdfbd55429b',
#   'name': 'BeanQuest Café',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJZ09IfDTLlzMRJRHWx_PouNk',
#   'plus_code': {'compound_code': 'JX5P+HR Manila, Metro Manila',
#    'global_code': '7Q62JX5P+HR'},
#   'rating': 3.7,
#   'reference': 'ChIJZ09IfDTLlzMRJRHWx_PouNk',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 12,
#   'vicinity': '1233 Barlin St, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.60443, 'lng': 120.9754485},
#    'viewport': {'northeast': {'lat': 14.60573807989272,
#      'lng': 120.9767821798927},
#     'southwest': {'lat': 14.60303842010728, 'lng': 120.9740825201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '8e5f79f0348dc5ecb19fd3ae362f4e8bb01c6793',
#   'name': 'Sidewalk Cafe',
#   'photos': [{'height': 3968,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115135184522624904236">Willie Castro</a>'],
#     'photo_reference': 'CmRaAAAAUQWjewyCI-IzCN8sa4Zqo3El_8aB-NioNx-1I6uMc2lR1K2vQrIJdLDZvbfIIAI50FosYzcJ4wQo6z6k0dEIpaeuE-tMdGajyeDUqpI3DS0ADUjssL_hzqXiI08UXoZlEhABQCe8AlVICMMMYM_sRL1QGhSBfKxg_IYkGbPcP7R6es7LZQ4UJA',
#     'width': 2976}],
#   'place_id': 'ChIJmdMoew_KlzMR4RrCCaz2now',
#   'plus_code': {'compound_code': 'JX3G+Q5 Manila, Metro Manila',
#    'global_code': '7Q62JX3G+Q5'},
#   'rating': 4.1,
#   'reference': 'ChIJmdMoew_KlzMR4RrCCaz2now',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 30,
#   'vicinity': '1149-51 Soler St, Binondo, Manila'},
#  {'geometry': {'location': {'lat': 14.5899336, 'lng': 120.9788593},
#    'viewport': {'northeast': {'lat': 14.59128042989272,
#      'lng': 120.9802380798927},
#     'southwest': {'lat': 14.58858077010728, 'lng': 120.9775384201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '90f59b0be3f3f3c538e52f4496485f8a42a8073e',
#   'name': 'Cioccolata Churros Cafe',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100276937762682865804">Keanu Molano</a>'],
#     'photo_reference': 'CmRaAAAARP_rHSBqpty9RAadH5zYZ6RnctXgVlARNZPxC4oD0h8A92d9BEXOGfycHplR0RrRs61gRrfB6MwivGXSwkTZXqpHVGU3EBRFthBtE31_Z9jDmmQw1DCu_pevXuc3tLl8EhAqoZx_wVAkYzeYJJWNF0vZGhS7EYJnGqLXEXnqVQ67QGOhAJ54vg',
#     'width': 4160}],
#   'place_id': 'ChIJUeR6hiLKlzMR4fPm9s-CYM8',
#   'plus_code': {'compound_code': 'HXQH+XG Manila, Metro Manila',
#    'global_code': '7Q62HXQH+XG'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJUeR6hiLKlzMR4fPm9s-CYM8',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 121,
#   'vicinity': 'G/F The Bayleaf Intramuros, Muralla corner Victoria streets, Intramuros, Manila'},
#  {'geometry': {'location': {'lat': 14.5906932, 'lng': 120.9762435},
#    'viewport': {'northeast': {'lat': 14.59206712989272,
#      'lng': 120.9775712298927},
#     'southwest': {'lat': 14.58936747010728, 'lng': 120.9748715701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '62cc2e46e15ea79c231fa0fb261d8d161b1b3130',
#   'name': 'Bloque 7 Cafe',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103188786310882862059">Ralph Nono</a>'],
#     'photo_reference': 'CmRaAAAAoIG3rOowkBLt6TtggOSPIFl7XejjWqx9xyceiCPiBumgAkNQRK76xe8fhQc1tZRtKEIbrE-0AEeyllqOJhfnFzt3q19QAsW8TPV0Huwy48dgWADTJ4cS-hdWilMuFI0nEhDstGoK3EtYod--7rk71VQvGhQf--2Qcfjoo8-15Bk-43tg8KtxjQ',
#     'width': 4608}],
#   'place_id': 'ChIJxZUMABjKlzMR5gOrO37MFxk',
#   'plus_code': {'compound_code': 'HXRG+7F Manila, Metro Manila',
#    'global_code': '7Q62HXRG+7F'},
#   'rating': 4.5,
#   'reference': 'ChIJxZUMABjKlzMR5gOrO37MFxk',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 18,
#   'vicinity': '658, Intramuros, Manila'},
#  {'geometry': {'location': {'lat': 14.5896914, 'lng': 120.9753284},
#    'viewport': {'northeast': {'lat': 14.59111317989272,
#      'lng': 120.9766102798927},
#     'southwest': {'lat': 14.58841352010727, 'lng': 120.9739106201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '93fa103db646fabe41f27a22910435164128c65f',
#   'name': "Barbara's Coffee Shop",
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110377770150558895658">Paul Ampunun</a>'],
#     'photo_reference': 'CmRaAAAAiE8yGoeBuXMlVkJqSM6H-B-9qJ6JQxYYIuUuW4N5iCuoQdWEa9zwQodHu6L3MBcw-eYhurcIfyOSZosDoOFgCHdQVELNVe09D6ilBAcjZBKaBSFwhEh2_xF-vJ2tn05gEhAm3VCglcbIPhssDPbCuF6KGhSgjg4a1U02bZogsZyvlewV7Om3AA',
#     'width': 3024}],
#   'place_id': 'ChIJ-7nLRz3KlzMRk5Um-W4Q9g4',
#   'plus_code': {'compound_code': 'HXQG+V4 Manila, Metro Manila',
#    'global_code': '7Q62HXQG+V4'},
#   'rating': 3.6,
#   'reference': 'ChIJ-7nLRz3KlzMRk5Um-W4Q9g4',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 20,
#   'vicinity': 'Real St, Intramuros, Manila'},
#  {'geometry': {'location': {'lat': 14.6056233, 'lng': 120.9964581},
#    'viewport': {'northeast': {'lat': 14.60689727989272,
#      'lng': 120.9978842298927},
#     'southwest': {'lat': 14.60419762010728, 'lng': 120.9951845701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'f16c89a0f8020e4abdfacc15d6e7fab583ea4fa8',
#   'name': "Governor's Cafe Manila",
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 738,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103479241753431406834">A Google User</a>'],
#     'photo_reference': 'CmRaAAAAK_wXYoEYXgOLOw_e9Vd6dJuGxNJ-UnKcEuNzKUvlYWY8zTlsdxOzToHuf7kvmeLC0KhiOWnMh0sF8VFQoXsTu5rlwljZKKo5lhTt9PuPF1UtqvM6xizqPXWsSTFywZRjEhCKf1jraw6YrKYRYhxLCUnQGhQbasEA8djz0cmWgADVwrqTJ0IRyQ',
#     'width': 1280}],
#   'place_id': 'ChIJ_RqlwkDJlzMRw-gdgx9sXB0',
#   'plus_code': {'compound_code': 'JX4W+6H Manila, Metro Manila',
#    'global_code': '7Q62JX4W+6H'},
#   'rating': 2,
#   'reference': 'ChIJ_RqlwkDJlzMRw-gdgx9sXB0',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1,
#   'vicinity': '515 Governor Forbes Inn, Lacson Ave. cor, Alcantara, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.6127404, 'lng': 120.9909483},
#    'viewport': {'northeast': {'lat': 14.61412017989272,
#      'lng': 120.9923309298927},
#     'southwest': {'lat': 14.61142052010728, 'lng': 120.9896312701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '758fe2b7ee70a8322df70bf7095dc8b56486dddd',
#   'name': 'iChill Theater Cafe',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102352063625148396295">Al Adrian</a>'],
#     'photo_reference': 'CmRaAAAAKyuo80EB1HVlMnVsXtt9f1lFpopAde8Wyah4vW3oMv9qF8qmhJB3H9lbDztdbSOd25-EIKmfayMnI3xSyI4ajidp48LJiRMAOTJ44FF6Wl8dXt5mtI8PKMojRXV7lYBiEhDloC0tQ2O7v_A8ugzoyLstGhQXF9yIrbaIbfbl2qwMrCCM7bOUaA',
#     'width': 4160}],
#   'place_id': 'ChIJuZl3GwG2lzMR5VwEapmHVKM',
#   'plus_code': {'compound_code': 'JX7R+39 Manila, Metro Manila',
#    'global_code': '7Q62JX7R+39'},
#   'rating': 4.2,
#   'reference': 'ChIJuZl3GwG2lzMR5VwEapmHVKM',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'store', 'establishment'],
#   'user_ratings_total': 88,
#   'vicinity': '1125 Dos Castillas St, Sampaloc, Manila'},
#  {'geometry': {'location': {'lat': 14.5723116, 'lng': 120.9831261},
#    'viewport': {'northeast': {'lat': 14.57371692989272,
#      'lng': 120.9844499298927},
#     'southwest': {'lat': 14.57101727010728, 'lng': 120.9817502701073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'e4903201d89b2ff29811f84f2f30ad66e0e5dcd6',
#   'name': 'Advocafe',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2160,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104967226150293138521">Todd XoX</a>'],
#     'photo_reference': 'CmRaAAAAd1xWs4V-0IhT2RlcqJCX4LEzLiMlLD719m8I_61-zNF6z_-9egZr35kOdaU4bUpEvDnebeitBgmk8nOOOo8ZnVyXNvSI4zGAnK8EerWGsDI4-0hxnwwbM3GNocgChTKcEhC5fxDerhrL8dSev9hlAdAxGhT2xlZHAhfLJqLBYjuGEDU7nz8n_Q',
#     'width': 3840}],
#   'place_id': 'ChIJ8bHAvCvKlzMRQTUfxYsMdVI',
#   'plus_code': {'compound_code': 'HXCM+W7 Manila, Metro Manila',
#    'global_code': '7Q62HXCM+W7'},
#   'rating': 4.5,
#   'reference': 'ChIJ8bHAvCvKlzMRQTUfxYsMdVI',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 25,
#   'vicinity': 'Quintos St, Malate, Manila'},
#  {'geometry': {'location': {'lat': 14.5722173, 'lng': 120.9848624},
#    'viewport': {'northeast': {'lat': 14.57358837989272,
#      'lng': 120.9862530798927},
#     'southwest': {'lat': 14.57088872010728, 'lng': 120.9835534201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '6c79cfcd0d11ec407f9091cd78a5010916a8dc72',
#   'name': 'La Scala Café',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3840,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115751295054447462094">La Scala Café</a>'],
#     'photo_reference': 'CmRaAAAAsnoLaAU3nIJWtvXnFJRLmQozIfFT5NZh7iAy_ATRnSRzNcoSXYuzy2gtn2lq4OY5qjn4d6rXuU0dIwC966di9KP9c2oXDJkLg13KwkJOI7acvYdYgN1rAnZgvkT_U8-FEhAcTxuKL0XeUThKL4MfIAHBGhT-zrz46Fd6QrflqBnJu5n9n8i7yg',
#     'width': 5760}],
#   'place_id': 'ChIJjSprsyvKlzMR5fgRn6GesyM',
#   'plus_code': {'compound_code': 'HXCM+VW Manila, Metro Manila',
#    'global_code': '7Q62HXCM+VW'},
#   'rating': 4.3,
#   'reference': 'ChIJjSprsyvKlzMR5fgRn6GesyM',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 81,
#   'vicinity': '2nd Floor, La Scala Residences Building, 1711 M, M. Adriatico St, Malate, Manila'},
#  {'geometry': {'location': {'lat': 14.5704603, 'lng': 120.983919},
#    'viewport': {'northeast': {'lat': 14.57175622989272,
#      'lng': 120.9851479798927},
#     'southwest': {'lat': 14.56905657010728, 'lng': 120.9824483201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': 'e28f6b0e29d31b4bf3288d19f340eefbb907adf5',
#   'name': 'blocleaf café',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 853,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101328499542044048435">A Google User</a>'],
#     'photo_reference': 'CmRZAAAAOPpGTSh_tAN8oVwW3iMfxpUhgyxHfICJSSVvMuZDuWr09ULa_7oKIpkJvYZ9AND6MvCMfTuxxMSZ8disSlo9P-DLzPUS2a1wERyqdGdSxsMURpgOIogEJ4ovaeMSBoOrEhAv6OUkbd7rRGGJtCKfPWZMGhTZxeCwmz_g25-4ss6iRvWxiHqopA',
#     'width': 1280}],
#   'place_id': 'ChIJfaKPFivKlzMR_RXJcq5pmsk',
#   'plus_code': {'compound_code': 'HXCM+5H Manila, Metro Manila',
#    'global_code': '7Q62HXCM+5H'},
#   'rating': 4.2,
#   'reference': 'ChIJfaKPFivKlzMR_RXJcq5pmsk',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 47,
#   'vicinity': '1850 M. H. Del Pilar St, Malate, Manila'},
#  {'geometry': {'location': {'lat': 14.5664462, 'lng': 120.9903107},
#    'viewport': {'northeast': {'lat': 14.56777142989272,
#      'lng': 120.9916032798927},
#     'southwest': {'lat': 14.56507177010728, 'lng': 120.9889036201073}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '67a37154ac045e4d41dbc2d2c983f7a343a69593',
#   'name': 'Makabata Guesthouse and Café',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 816,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109398749462398651747">Adrian Scerri</a>'],
#     'photo_reference': 'CmRaAAAAWwS-hI1amhSqdXACIVzZ-AnfPYgM0S4I49tdttR3l0uB9GamBhN_NhRCAHuTs7g59BXnOHgVfSMdognKYm3mFkDaAN35zhH4EyOQcISwKDWCxez7l5VfdyxC5whtl6q-EhDmQDtr7jtLvP8TFTxHI9OVGhQ8vqMjAb5NyU9Mo9LO7iy71XNP0A',
#     'width': 612}],
#   'place_id': 'ChIJB96moX_JlzMRvMVbRsG5r6s',
#   'plus_code': {'compound_code': 'HX8R+H4 Manila, Metro Manila',
#    'global_code': '7Q62HX8R+H4'},
#   'rating': 3.8,
#   'reference': 'ChIJB96moX_JlzMRvMVbRsG5r6s',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'lodging', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 48,
#   'vicinity': '2218 Leveriza St, Malate, Manila'}]
